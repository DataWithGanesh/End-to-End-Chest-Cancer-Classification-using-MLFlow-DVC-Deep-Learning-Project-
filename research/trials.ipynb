# %%
print("OK")
# Out:
# OK

# %%
d = {"key":"value","key1": "value1"}

# %%
d["key"]
# Out:
# 'value'

# %%
d.key
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 d.key
#
# AttributeError: 'dict' object has no attribute 'key'

# %%
from box import ConfigBox

# %%
d2 = {"key":"value","key1": "value1"}

# %%
d2 = ConfigBox(d2)

# %%
d2
# Out:
# ConfigBox({'key': 'value', 'key1': 'value1'})

# %%
d2.key1
# Out:
# 'value1'

# %%
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# '33'

# %%
from ensure import ensure_annotations

# %%
@ensure_annotations
def get_product(x:int, y:int):
    return x*y

# %%
get_product(x = 2, y = 3)
# Out:
# 6

# %%
get_product(x = 2, y = "3")
# Out:
# ---------------------------------------------------------------------------
# EnsureError                               Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_product(x = 2, y = "3")
#
# File c:\Users\Ganesh\anaconda3\envs\cancer\lib\site-packages\ensure\main.py:803, in WrappedFunction.__call__(self, *args, **kwargs)
#     798     if not isinstance(value, templ):
#     799         msg = (
#     800             "Argument {arg} of type {valt} to {f} "
#     801             "does not match annotation type {t}"
#     802         )
# --> 803         raise EnsureError(msg.format(
#     804             arg=arg, f=self.f, t=templ, valt=type(value)
#     805         ))
#     807 return self.f(*args, **kwargs)
#
# EnsureError: Argument y of type <class 'str'> to <function get_product at 0x000002812A180940> does not match annotation type <class 'int'>

# %% [markdown]
# ### Download data from gdrive

# %%
# !pip install gdown --upgrade
# Out:
# Requirement already satisfied: gdown in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from gdown) (4.14.2)
# Requirement already satisfied: filelock in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from gdown) (3.19.1)
# Requirement already satisfied: requests[socks] in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from gdown) (2.32.5)
# Requirement already satisfied: tqdm in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in c:\users\ganesh\anaconda3\envs\cancer\lib\site-packages (from tqdm->gdown) (0.4.6)

# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1BwzdGrU5OkvWnyhyVSMpPFMsuzPARpyb/view?usp=sharing"

# %%
type(url)
# Out:
# str

# %%
file_id = url.split("/")[-2]
file_id
# Out:
# '1BwzdGrU5OkvWnyhyVSMpPFMsuzPARpyb'

# %%
prefix = 'https://drive.google.com/uc?/export=download&id='
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1BwzdGrU5OkvWnyhyVSMpPFMsuzPARpyb
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1BwzdGrU5OkvWnyhyVSMpPFMsuzPARpyb&confirm=t&uuid=8c791e07-8a96-45c6-bda4-0b0624677604
# To: c:\Users\Ganesh\AIML Engineer\DL (End-to-End Project)\End-to-End-Chest-Cancer-Classification-using-MLFlow-DVC-Deep-Learning-Project-\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [00:02<00:00, 19.4MB/s]
# 'Chest-CT-Scan-data.zip'
